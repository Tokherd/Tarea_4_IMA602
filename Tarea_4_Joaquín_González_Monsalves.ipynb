# %% [markdown]
# # Tarea 4 IMA-602-1
#
# # Estudiante: Joaquín Gonzalez Monsalves
# # IMA602-1: HERRAMIENTAS BASICAS PARA EL ANALISIS DE DATOS

# %% [markdown]
# # Estructuracion del trabajo por secciones:
# # Esto es considerando solo los datos de la encuesta casen, no necesariamente representan la realidad

# %% [markdown]
# - Seccion 1: Se presentan las preguntas a responder
#
# - Seccion 2: Codigos utilizados de la casen para el trabajar y su clasificacion y que tipo de variable es
#
# - Seccion 3: Lectura de datos
#
# - Seccion 4: Se cuantizan la cantidad de datos faltantes
#
# - Seccion 5 :Realizacion de estadistica descriptiva de las variables de interes de manera individual y ver decir que significan sus parametros cuando tienen sentido
#
# - Seccion 6: Realizacion de graficos que sirven para responder a las preguntas presentadas
#
# - Seccion 7: Respuesta a las preguntas de acuerdo a lo anterior

# %% [markdown]
# # Seccion 1
# # Preguntas a responder y con las variables correspondientes:

# %% [markdown]
# - Pregunta 1: ¿Que sexo predomina mas en las zonas urbanas y rurales?  (cualitativo con cualitativo) variables:(sexo),(zona)
#
#
# - Pregunta 2: ¿Acaso las personas que tienen dificultad de ver incluso con lentes  tendran dificultad para caminar o subir escaleras? (cualitativo con cualitativo) variables:(h10a), (h10c)
#
#
# - Pregunta 3: ¿hay mas del sexo femenino o masculino en el pais ?(cualitativo) variable: (sexo)
#
#
# - Pregunta 4: ¿Las personas que tienen dificultades para comunicarse sabiendo leer y escribir?(Cualitativo con cualitativo)
#   variable:(h10f) (e1)
#
#
# - Pregunta 5: ¿Se relacionara la dificultad para recordar o para concentrarse con presentar dificultades para cuidado personal tales como asearse y vestirse?(Cualitativo con cualitativo) variable: (h10d) (h10e)
#
#
# - Pregunta 6: ¿Las personas que quieren trabajar mas horas a la semana son aquellos con menor jornada laboral?(Cuantitativo con cuantitativo) variables: (o10) (o11)
#
#
# - Pregunta 7: ¿La razon principal para compartir vivenda con otro hogar tendra alguna relacion con la cantidad de hogares por vivienda? (cuantitativo con cualitativo)  variables:  (v31) (v28)
#
#
# - Pregunta 8: ¿Habra una relacion entre tener tarjeta de credito con la cantidad de hijos que se tiene?(cualitativo con cuantitativo)  variables: (y27e)   (s4)
#
#
# - Pregunta 9: ¿La cantidad de hijos nacidos en la vida incide sobre la cantidad de hogares en una vivienda? (cuantitativo con cuantitativo) variables: (s4) (v28)
#
#
# - Pregunta 10: ¿La Cantidad de horas que trabaja semanalmente influye en el estado civil? (cuantitativo con cualitativo)
#   variables: (o10) (ecivil)

# %% [markdown]
# # Seccion 2
# # Codigos utilizados de la casen para acceder a los datos y su clasificación segun el tipo de variable

# %% [markdown]
# - Sexo:  1 es hombre, 2 es mujer (sexo) cualitativo nominal
#
# - zona urbana o rural: 1 es urbana, 2 es rural (zona) cualitativo nominal
#
# - dificultad para comunicarse: (h10f) cualitativo nominal
#
# - Dificultad de ver incluso con lentes (h10a) cualitativo ordinal
#
# - Dificultad para caminar o subir escaleras (h10c) cualitativo ordinal
#
# - Sabe leer y escribir? (e1)  cualitativo ordinal
#
# - Cuantas horas trabaja habitualmente a la semana (o10) cuantitativo continua
#
# - Si esta dispuesto a trabajar mas horas a la semana (o11) cualitativo nominal
#
# - Cantidad de hogares por vivienda? (v28)    cuantitativo discreta
#
# - Razon principal para compartir esta vivienda con otro hogar (v31) cualitativo nominal
#
# - Estado civil (ecivil) cualitativo nominal
#
# - Tiene tarjeta de credito bancaria (y27e) cualitativa nominal
#
# - cantidad de hijos nacidos en su vida (s4) cuantitativa discreta ya que se elimina la categoria 99 que es no sabe/no responde y se tienen solo numeros
#
# - tiene dificultades para recordar o concentrarse (h10d)
#
# - tiene dificultades para cuidado personal (h10e)

# %% [markdown]
# # Seccion 3
# # Lectura datos

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#Para ocultar los warnings
import warnings
warnings.filterwarnings("ignore")

# %%
import pyreadstat
# Leer el archivo .sav
archivo_sav = 'Casen_2017.sav'
datos, metadatos = pyreadstat.read_sav(archivo_sav)
datos.info()
datos.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216439 entries, 0 to 216438
# Columns: 804 entries, folio to pobreza_multi_5d
# dtypes: float64(768), object(36)
# memory usage: 1.3+ GB
#           folio    o   id_vivienda  hogar  region  provincia  comuna  zona  \
# 0  1.101100e+11  1.0  1.101100e+09    1.0     1.0       11.0  1101.0   1.0
# 1  1.101100e+11  1.0  1.101100e+09    1.0     1.0       11.0  1101.0   1.0
# 2  1.101100e+11  1.0  1.101100e+09    1.0     1.0       11.0  1101.0   1.0
# 3  1.101100e+11  2.0  1.101100e+09    1.0     1.0       11.0  1101.0   1.0
# 4  1.101100e+11  1.0  1.101100e+09    1.0     1.0       11.0  1101.0   1.0
#
#    expr  expc  ...  hh_d_estado  hh_d_servbas  hh_d_entorno  hh_d_accesi  \
# 0  39.0  33.0  ...          0.0           1.0           1.0          0.0
# 1  39.0  33.0  ...          1.0           0.0           0.0          0.0
# 2  39.0  33.0  ...          1.0           0.0           1.0          0.0
# ...

# %%
datos.drop(datos[datos['s4']==99].index,inplace=True) #se eliminan los datos de la categoria s4 con valor
                                                      #99 que es no sabe/no responde
                                                      #para que sea una variable cuantitativa discreta

# %% [markdown]
# # Seccion 4
# # Cuantizacion de datos faltantes por variables

# %%
datos.sexo.isnull().sum()/len(datos) * 100 #sexo
#cero datos faltantes
# Out:
# 0.0

# %%
datos.zona.isnull().sum()/len(datos) * 100  # zona rural o urbana
#cero datos faltantes
# Out:
# 0.0

# %%
datos.h10f.isnull().sum()/len(datos) * 100 # dificultades para comunicarse
# Aproximadamente el 6% de observaciones de la variable h10f son datos faltantes
# Out:
# 6.084142092530147

# %%
datos.h10d.isnull().sum()/len(datos) * 100 #dificualtades para recordar o concentrarse
# Aproximadamente el 6% de observaciones de la variable h10d son datos faltantes
# Out:
# 6.084142092530147

# %%
datos.h10a.isnull().sum()/len(datos) * 100 #dificualtad de ver incluso con lentes
# Aproximadamente el 6% de observaciones de la variable h10a son datos faltantes
# Out:
# 6.084142092530147

# %%
datos.h10c.isnull().sum()/len(datos) * 100 #dificualtad para caminar o subir escaleras
# Aproximadamente el 6% de observaciones de la variable h10c son datos faltantes
# Out:
# 6.084142092530147

# %%
datos.e1.isnull().sum()/len(datos) * 100 #sabe leer y escribir
# Aproximadamente el 19% de observaciones de la variable e1 son datos faltantes
# Out:
# 19.231811091287817

# %%
datos.e7_cod_area.isnull().sum()/len(datos) * 100 #Nombre de la carrera o programa de estudios
# Aproximadamente el 77% de observaciones de la variable e7 son datos faltantes
# Out:
# 77.78753374370663

# %%
datos.o10.isnull().sum()/len(datos) * 100 #Cuantas horas trabaja habitualmente a la semana
# Aproximadamente el 57% de observaciones de la variable o10 son datos faltantes
# Out:
# 57.37784544681806

# %%
datos.o11.isnull().sum()/len(datos) * 100 # Si esta dispuesto a trabajar mas horas a la semana
# Aproximadamente el 57% de observaciones de la variable o11 son datos faltantes
# Out:
# 57.32273461800723

# %%
datos.v28.isnull().sum()/len(datos) * 100 # Cuantos hogares hay en esta vivienda
#no hay datos faltantes
# Out:
# 0.0

# %%
datos.v31.isnull().sum()/len(datos) * 100  # Razon principal para compartir esta vivienda con otro hogar
# Aproximadamente el 93% de observaciones de la variable v31 son datos faltantes
# Out:
# 93.97423802273556

# %%
datos.ecivil.isnull().sum()/len(datos) * 100 # Estado civil
#no hay datos faltantes
# Out:
# 0.0

# %%
datos.y27e.isnull().sum()/len(datos) * 100# Tiene tarjeta de credito bancaria
# Aproximadamente el 19% de observaciones de la variable y27e son datos faltantes
# Out:
# 19.231811091287817

# %%
datos.s4.isnull().sum()/len(datos) * 100 #cantidad de hijos nacidos en su vida
# Aproximadamente el 15% de observaciones de la variable s4 son datos faltantes
# Out:
# 15.370316747153387

# %% [markdown]
# # Seccion 5
# # Estadistica descriptiva de cada variable

# %%
datos.sexo.describe().loc[['mean', 'std','min','25%','50%','75%','max']] #variable sexo
# Out:
# mean    1.524744
# std     0.499389
# min     1.000000
# 25%     1.000000
# 50%     2.000000
# 75%     2.000000
# max     2.000000
# Name: sexo, dtype: float64

# %% [markdown]
# no tiene sentido analizar una variable categorica de este estilo

# %%
datos.zona.describe().loc[['mean', 'std','min','25%','50%','75%','max']] #variable zona
# Out:
# mean    1.187694
# std     0.390469
# min     1.000000
# 25%     1.000000
# 50%     1.000000
# 75%     1.000000
# max     2.000000
# Name: zona, dtype: float64

# %% [markdown]
# no tiene sentido analizar una variable categorica de este estilo

# %%
datos.h10e.describe().loc[['mean', 'std','min','25%','50%','75%','max']] #variable dificualtades para comunicarse
# Out:
# mean    1.073501
# std     0.501907
# min     1.000000
# 25%     1.000000
# 50%     1.000000
# 75%     1.000000
# max     9.000000
# Name: h10e, dtype: float64

# %% [markdown]
# no tiene sentido analizar la variable con los valores que tiene (categorica)

# %%
datos.h10a.describe().loc[['mean', 'std','min','25%','50%','75%','max']] #dificultad de ver incluso con lentes
# Out:
# mean    1.156072
# std     0.553081
# min     1.000000
# 25%     1.000000
# 50%     1.000000
# 75%     1.000000
# max     9.000000
# Name: h10a, dtype: float64

# %% [markdown]
# no tiene sentido analizar la variable  con los valores que presenta(categorica)

# %%
datos.h10c.describe().loc[['mean', 'std','min','25%','50%','75%','max']]#dificualtad para caminar o subir escaleras
# Out:
# mean    1.151149
# std     0.589460
# min     1.000000
# 25%     1.000000
# 50%     1.000000
# 75%     1.000000
# max     9.000000
# Name: h10c, dtype: float64

# %% [markdown]
# no tiene sentido analizar la variable  con los valores que presenta(categorica)

# %%
datos.e1.describe().loc[['mean', 'std','min','25%','50%','75%','max']] #sabe leer y escribir
# Out:
# mean    1.116482
# std     0.588375
# min     1.000000
# 25%     1.000000
# 50%     1.000000
# 75%     1.000000
# max     9.000000
# Name: e1, dtype: float64

# %% [markdown]
# no tiene sentido analizar la variable  con los valores que se presenta(categorica)

# %%
datos.o10.describe().loc[['mean', 'std','min','25%','50%','75%','max']]#Cuantas horas trabaja habitualmente a la semana
# Out:
# mean     42.910574
# std      14.805197
# min       1.000000
# 25%      40.000000
# 50%      45.000000
# 75%      45.000000
# max     220.000000
# Name: o10, dtype: float64

# %% [markdown]
# - en promedio se trabaja 42.9 horas a la semana
# - su desviacion estandar es de 14.8 horas
# - el minimo de horas que se trabaja a la semana es de 1 hora
# - el maximo de horas es de 220 horas que se trabaja a la semana, lo cual al parecer es un error de tipeo, ya que maximo se podrian trabajar 168 horas sin dormir ni comer. por lo cual es un dato atipico que podria afectar a las otras medidas
# - el 25% de los trabajadores trabaja 40 horas o menos
# - el 50% de los trabajadores trabaja 45 horas o menos
# - el 75% de los trabajadores trabaja 45 horas o menos

# %%
datos.o11.describe().loc[['mean', 'std','min','25%','50%','75%','max']] #Si esta dispuesto a trabajar mas horas a la semana
# Out:
# mean    2.256046
# std     1.122211
# min     1.000000
# 25%     1.000000
# 50%     3.000000
# 75%     3.000000
# max     9.000000
# Name: o11, dtype: float64

# %% [markdown]
# no tiene sentido analizar los valores de esta variable categorica por los valores que tiene

# %%
datos.v28.describe().loc[['mean', 'std','min','25%','50%','75%','max']] # Cuantos hogares hay en esta vivienda
# Out:
# mean     1.084819
# std      0.394809
# min      1.000000
# 25%      1.000000
# 50%      1.000000
# 75%      1.000000
# max     10.000000
# Name: v28, dtype: float64

# %% [markdown]
# - en promedio se tiene 1.08 hogares por vivienda lo cual no tiene sentido
# - La desviacion estandar es aproximadamente 0.4
# - el minimo de hogares por vivienda es de 1
# - el 25% de hogares por vivienda es 1
# - el 50% de hogares por vivienda es 1
# - el 75% de hogares por vivienda es 1
# - maximo de viviendas por hogar es 10

# %%
datos.v31.describe().loc[['mean', 'std','min','25%','50%','75%','max']] # Razon principal para compartir esta vivienda con otro hogar
# Out:
# mean     8.101535
# std     19.277008
# min      1.000000
# 25%      2.000000
# 50%      3.000000
# 75%      7.000000
# max     99.000000
# Name: v31, dtype: float64

# %% [markdown]
# no tiene sentido analizar por los valores que presenta la variable categorica

# %%
datos.ecivil.describe().loc[['mean', 'std','min','25%','50%','75%','max']] # Estado civil
# Out:
# mean    5.088682
# std     3.190747
# min     1.000000
# 25%     1.000000
# 50%     7.000000
# 75%     8.000000
# max     8.000000
# Name: ecivil, dtype: float64

# %% [markdown]
# no tiene sentido analizar por los valores de la variable categorica

# %%
datos.y27e.describe().loc[['mean', 'std','min','25%','50%','75%','max']]# Tiene tarjeta de credito bancaria
# Out:
# mean    2.002677
# std     0.997826
# min     1.000000
# 25%     2.000000
# 50%     2.000000
# 75%     2.000000
# max     9.000000
# Name: y27e, dtype: float64

# %% [markdown]
# no tiene sentido analizar por los valores de la variable categorica

# %%
datos.s4.describe().loc[['mean', 'std','min','25%','50%','75%','max']] #cantidad de hijos nacidos en su vida
# Out:
# mean     1.77719
# std      1.90405
# min      0.00000
# 25%      0.00000
# 50%      2.00000
# 75%      3.00000
# max     22.00000
# Name: s4, dtype: float64

# %% [markdown]
# - El promedio nos dice 1.7 cantidad de hijos nacidos lo cual no tiene sentido, porque no se puede tener 1.7 hijos
# - la desviacion estandar es 1.9 aproximadamente
# - el minimo de hijos nacidos en la vida de alguien es 0
# - el 25% de hijos nacidos en la vida de alguien es 0
# - el 50% de hijos nacidos en la vida de alguien es 2
# - el 75% de hijos nacidos en la vida de alguies es 3
# - el maximo podria ser un error de tipeo o es un dato atipico que puede ocurrir pero no muy frecuente

# %% [markdown]
# # Seccion 6

# %%
#para la pregunta 1
plt.figure(figsize=(4,4))
count_plot = sns.countplot(x = datos.zona, hue = datos.sexo)
plt.title('Gráfico de barras para la variable Sexo por zona',y=1.01)
plt.ylabel('Conteo')
plt.xlabel('Sexo')
plt.show()

# %%
# Para la pregunta 2

plt.figure(figsize=(10,10))
count_plot = sns.countplot(x = datos.h10a, hue = datos.h10c)
plt.title('Gráfico de barras para la variable ver con dificultad a pesar de usar lentes con problemas para caminar y subir escaleras',y=1.01)
plt.ylabel('Conteo')
plt.xlabel('dificultad de ver a pesar de usar lentes')
plt.show()

# %%
#pregunta 3

conteos = datos['sexo'].value_counts()
d=['mujeres', 'hombres']
# Crear el gráfico de torta

plt.figure(figsize=(4,4)) #plt. hace referencia a la librería matplotlib
plt.pie(conteos, labels=d, autopct='%0.1f%%')

# Agregar un título al gráfico
plt.title('Distribución de la variable sexo',y=1.1) 

# Mostrar el gráfico
plt.axis('equal')  # Para que el gráfico sea un círculo en lugar de una elipse
plt.show()

# %%
#pregunta 4

plt.figure(figsize=(8,8))
count_plot = sns.countplot(x = datos.h10f, hue = datos.e1)
plt.title('Gráfico de barras para la variable dificultad para comunicarse con saber leer y escribir',y=1.01)
plt.ylabel('Conteo')
plt.xlabel('dificultad para comunicarse')
plt.show()

# %%
#pregunta 5
plt.figure(figsize=(4,4))
count_plot = sns.countplot(x = datos.h10d, hue = datos.h10e)
plt.title('Gráfico de barras para la variable dificultad para recordar o concentrarse por dificultades para aseo personal',y=1.01)
plt.ylabel('Conteo')
plt.xlabel('dificultad dificultades para recordar o concentrarse')
plt.show()

# %%
# pregunta 6
plt.figure(figsize=(50,50))
count_plot = sns.countplot(x = datos.o10, hue = datos.o11)
plt.title('Gráfico de barras para la variable diespuesto a trabajar mas horas por cuantas horas trabaja semanalmente',y=1.01)
plt.ylabel('Conteo')
plt.xlabel('horas trabajadas normalmente')
plt.show()

# %%
# pregunta 7

plt.figure(figsize=(12,12))
count_plot = sns.countplot(x = datos.v31, hue = datos.v28)
plt.title('Gráfico de barras para la variable razon principal para compartir vivienda por cantidad de hogares',y=1.01)
plt.ylabel('Conteo')
plt.xlabel('razon principal para compartir vivienda ')
plt.show()

# %%
# pregunta 8
data_tarjeta = datos['y27e']
data_hijos = datos['s4']

# %%
plt.figure(figsize=(20,20))
sns.histplot(data_tarjeta, color='red', label='tarjeta', alpha=0.5)
sns.histplot(data_hijos, color='blue', label='hijos', alpha=0.5)
plt.legend(loc='upper right')
plt.title('Histograma de la variable cantidad de tarjetas agrupada por cantidad de hijos',y=1.01)
plt.xlabel('cantidad de hijos')
plt.ylabel('Frecuencia')
plt.show()

# %%
#pregunta 9

plt.figure(figsize=(20,20))
count_plot = sns.countplot(x = datos.v28, hue = datos.s4)
plt.title('Gráfico de barras para la variable cantidad de hijos que ha tenido en su vida por cantidad de hogares en la vivienda',y=1.01)
plt.ylabel('Conteo')
plt.xlabel('cantidad de hogares por vivienda')
plt.show()

# %%
#pregunta 10


plt.figure(figsize=(4,4))
sns.boxplot(x=datos['ecivil'],y=datos['o10']) #x debe ser categórica e y continua
plt.title('Diagrama de caja de la variable estado civil por cantidad de horas trabajadas',y=1.01)
plt.xlabel('estado civil')
plt.ylabel('cantidad de horas trabajadas')
plt.show()

# %%
plt.figure(figsize=(50,50))
intervalos = [0,15,30,60,90,120,220]
count_plot = sns.countplot(x = datos['o10'], hue =datos.ecivil)
plt.title('Gráfico de barras para la variable cantidad de horas trabajadas semanales por estado civil',y=1.01)
plt.ylabel('Conteo')
plt.xlabel('cantidad de horas trabajadas semanalmente')
plt.xticks(intervalos)
plt.show()

# %% [markdown]
# # Seccion 7 respuetas a las preguntas

# %% [markdown]
# - Pregunta 1: ¿Que sexo predomina mas en las zonas urbanas y rurales?  (cualitativo con cualitativo)variables:(sexo),(zona)     Respuesta: el sexo femenino esta mas presente en la zona urbana y en la rural por poco.
#
#
# - Pregunta 2: ¿Acaso las personas que tienen dificultad de ver incluso con lentes  tendran dificultad para caminar o subir escaleras? (cualitativo con cualitativo) variables:(h10a), (h10c) Respuesta: al parecer no hay relacion estadistica que evidencie una relacion entre ellas.
#
#
# - Pregunta 3: ¿hay mas del sexo femenino o masculino en el pais ?(cualitativo) variable: (sexo)  Respuesta: el sexo femenino predomina a nivel pais.
#
#
# - Pregunta 4: ¿Las personas que tienen dificultades para comunicarse sabiendo leer y escribir?(Cualitativo con cualitativo)
#   variable:(h10f) (e1)  Respuesta: las personas no necesariamente presentan dificultades para comunicarse, sabiendo leer y escribir.
#
#
# - Pregunta 5: ¿Se relacionara la dificultad para recordar o para concentrarse con presentar dificultades para cuidado personal tales como asearse y vestirse?(Cualitativo con cualitativo) variable: (h10d) (h10e)  Respuesta:  no hay evidencia estadistica para decir que se relacionan.
#
#
# - Pregunta 6: ¿Las personas que quieren trabajar mas horas a la semana son aquellos con menor jornada laboral?(Cuantitativo con cuantitativo) variables: (o10) (o11)  Respuesta: no es concluyente el grafico , por lo cual decimos que no hay evidencia estadistica para relaconar las variables.
#
#
# - Pregunta 7: ¿La razon principal para compartir vivenda con otro hogar tendra alguna relacion con la cantidad de hogares por vivienda? (cuantitativo con cualitativo)  variables:  (v31) (v28) Respuesta: Al parecer si, tiene que ver con el nivel de ingresos de personas, ya que no pueden costear una casa de manera independiente al menos la mas fuerte razon para hacerlo.
#
#
# - Pregunta 8: ¿Habra una relacion entre tener tarjeta de credito con la cantidad de hijos que se tiene?(cualitativo con cuantitativo)  variables: (y27e)   (s4) Respuesta: la mayor parte esta concentrada en tener tarjeta de credito si tiene 2 hijos o 1 pero en general no se observa una relacion muy clara.
#
#
# - Pregunta 9: ¿La cantidad de hijos nacidos en la vida incide sobre la cantidad de hogares en una vivienda? (cuantitativo con cuantitativo) variables: (s4) (v28)  Respuesta: No se observa una incidencia sobre la cantidad de hogares, quizas otras variables podrian aportar.
#
#
# - Pregunta 10: ¿La Cantidad de horas que trabaja semanalmente influye en el estado civil? (cuantitativo con cualitativo)
#   variables: (o10) (ecivil)  Respuesta: en el intervalo de 31 horas a 60 horas se tiene que son casados y solteros, no hay evidencia estadistica para establecer una influencia directa sobre estas
